# %%
import pandas as pd
from pandas import Series, DataFrame
import datetime as dt
import string
figsize(18,6)

# %% [markdown]
# # This creates some mock Futures Data

# %%
source = DataFrame(np.random.uniform(100, 120, [30,30]))
cols = ['Price', 'Volume', 'Open Interest']
scale = (len(source.columns) / len(cols))
source.columns = [scale  * cols]
sym = lambda x: np.random.choice([abc for abc in x], 
                                 np.random.choice([2,3]))
month = lambda x: np.random.choice([abc for abc in x], 
                                 np.random.choice([1]))

contracts = np.ravel([[(''.join(month(string.letters[:26])) + 
             str(np.random.choice([14,15,16])))] * len(cols)
             for x in xrange(len(source.columns) / len(cols)/ 2)])

level_1 = len(source.columns) / len(contracts) * list(contracts)

numsyms = len(source.columns) / (len(set(level_1)) * len(cols))
underlyings = [''.join(sym(string.letters[:26])) for x in xrange(numsyms)]
level_0 = np.ravel([[sym] * len(set(level_1)) * len(cols) for sym in underlyings])

source.columns = pd.MultiIndex.from_tuples(zip(level_0, level_1, source.columns))
source.index = pd.date_range(start= dt.datetime.utcnow() - dt.timedelta(days=len(source.index)-1), 
                             end = dt.datetime.utcnow(), freq='D')

# %%
source.head(10).T.head(8).T
# Out:
#                                    QQD                                         \
#                                    D15                                    O14
#                                  Price      Volume  Open Interest       Price
# 2013-12-09 23:06:32.171991  117.537369  101.972920     119.667082  106.747734
# 2013-12-10 23:06:32.171991  105.502837  110.996396     104.561839  115.516060
# 2013-12-11 23:06:32.171991  119.789303  111.999422     106.903583  112.731226
# 2013-12-12 23:06:32.171991  110.610071  104.354886     101.154881  108.326297
# 2013-12-13 23:06:32.171991  116.906584  117.195978     115.404234  114.631815
# 2013-12-14 23:06:32.171991  113.165475  117.856341     103.665495  119.087036
# 2013-12-15 23:06:32.171991  109.573607  111.174034     110.909063  105.473840
# 2013-12-16 23:06:32.171991  102.072830  119.432812     103.199871  105.778350
# 2013-12-17 23:06:32.171991  117.161606  117.580322     110.723821  106.795136
# 2013-12-18 23:06:32.171991  101.646075  103.588993     112.073728  105.982258
#
#
#                                                               A15
#                                 Volume  Open Interest       Price      Volume
# 2013-12-09 23:06:32.171991  115.155679     113.891780  100.955019  100.777109
# 2013-12-10 23:06:32.171991  109.224457     101.397986  106.220440  116.366370
# 2013-12-11 23:06:32.171991  118.794959     105.206007  106.987991  111.708500
# 2013-12-12 23:06:32.171991  108.434552     105.127710  119.527528  119.142699
# 2013-12-13 23:06:32.171991  112.000703     118.547840  115.777304  106.045433
# 2013-12-14 23:06:32.171991  118.539229     118.425844  119.286379  106.848889
# 2013-12-15 23:06:32.171991  118.439656     118.960870  115.190497  109.152421
# 2013-12-16 23:06:32.171991  114.881873     119.634713  117.071833  100.501177
# 2013-12-17 23:06:32.171991  103.115955     110.539481  104.591206  103.787355
# 2013-12-18 23:06:32.171991  106.952479     109.524013  101.097453  113.560398

# %% [markdown]
# # Here is my cheap replica of zipline that reads in the data source, which filters data as passed to handle_data only giving tradeable access to the front month. This is by no means an api to strictly follow, more of a conceptual implementation

# %%
class Trader(object):
    def run(self, source):
        self.universe = Universe(source)
        self.initialize()
        [self.onEvent(self.universe.bars[bar].syms) for bar in self.universe.bars]
        DataFrame(self.hist).plot()
    def onEvent(self, bar):
        self.bar = bar
        self.handle_data(self.roll())
   
    def roll(self):
        def groupby():
            #There should probably also be some logic here 
            refs = [DataFrame([contract.__dict__ for contract in self.bar[sym]]
                             ).set_index('contract') for sym in self.bar]
            refs = [frame['oi'].idxmax() for frame in refs]
            refs = dict(zip([sym for sym in self.bar], refs))
            front_month = [{sym : contract for contract in 
                           self.bar[sym] if contract.contract == refs[sym]} for sym in self.bar]
            return reduce(lambda a, b: dict(a, **b), front_month)
            
            # here we would compare the change in reference
            # and execute offsetting orders
            # for changes in references:
            #     self.order(new_ref, self.portfolio.positions[old_ref])
            #     self.order(old_ref, -self.portfolio.positions[old_ref])
            
        return groupby()
        
    
class Universe(object):
    def __init__(self, source):
        self.bars = {}
        for row in source.iterrows():
            self.bars[row[1].name] = BarData(row)
    def keys(self):
        return self.__dict__.keys()
            
            
class BarData(object):
    def __init__(self, row):
        self.syms = {}
        for sym in row[1].index.levels[0]:
                for exp in row[1].index.levels[1]:
                    if sym in self.syms:
                        self.syms[sym].append(SymData(sym, exp, row[1][sym][exp]))
                    else:
                        self.syms[sym] = [SymData(sym, exp, row[1][sym][exp])]
    def keys(self):
        return self.__dict__.keys()
    
class SymData(object):
    def __init__(self, sym, exp, fields):
        self.underlying = sym
        self.contract = exp
        self.price = fields['Price']
        self.volume = fields['Volume']
        self.oi = fields['Open Interest']
    def keys(self):
        return self.__dict__.keys()
    
#========================================================================================================
#========================================================================================================
#=================================      USER DEFINED CLASS     ==========================================
#========================================================================================================
#========================================================================================================

class TraderBot(Trader):
    def initialize(self):
        # here you would initialize your roll strategy
        # then either add it as a method to TradingAlgorithm
        # or close with roll decorator, probably the decorator
        
        # I am hoping we can devise a clean api that can also be applied
        # to data returned from BatchTransform such that we have historical
        # data series that matches what the strategy would actually trade
        
        #@roll
        self.lambda_ = (lambda x: x.oi.max())
        self.hist = {}
    
    def handle_data(self, data):
        for sym in data.keys():
            print sym, data[sym].contract, data[sym].price
            if sym in self.hist.keys():
                self.hist[sym].append(data[sym].price)
            else:
                self.hist[sym] = [data[sym].price]
TraderBot().run(source)
# Out:
# QQD D15 101.712438264
# XFH A15 105.578925911
# QQD D15 116.827469527
# XFH A15 108.936444421
# QQD A15 119.527528359
# XFH J16 116.45894061
# QQD R15 108.835570495
# XFH R15 117.943929759
# QQD J16 111.291087066
# XFH R15 115.712686545
# QQD A15 118.243547064
# XFH O14 101.308739526
# QQD R15 106.612880263
# XFH A15 106.299005557
# QQD D15 115.890815822
# XFH A15 102.203642892
# QQD A15 110.760808148
# XFH J16 113.781225053
# QQD O14 107.203598681
# XFH A15 114.247448133
# QQD R15 100.70699174
# XFH R15 110.039255334
# QQD A15 103.451158165
# XFH D15 113.255338925
# QQD R15 110.484229133
# XFH J16 116.720916808
# QQD O14 105.734778601
# XFH D15 103.820093234
# QQD R15 102.151359382
# XFH R15 113.128211397
# QQD J16 112.308990596
# XFH R15 115.703891372
# QQD A15 106.987990618
# XFH A15 106.555964542
# QQD D15 111.679140087
# XFH J16 103.882177515
# QQD O14 117.330631155
# XFH J16 111.930087953
# QQD O14 119.087036454
# XFH A15 100.239894595
# QQD
#  D15 117.537369401
# XFH R15 108.226166061
# QQD D15 106.987950502
# XFH A15 100.148400356
# QQD J16 105.470729989
# XFH R15 108.106539699
# QQD R15 107.678943113
# XFH J16 108.000223117
# QQD A15 106.22044005
# XFH O14 101.904766719
# QQD A15 104.591206376
# XFH D15 119.420107073
# QQD R15 108.969045676
# XFH J16 105.966004123
# QQD D15 104.764351113
# XFH D15 117.372744934
# QQD O14 114.631814914
# XFH J16 111.12915323
# QQD O14 105.778349549
# XFH J16 100.831275187
